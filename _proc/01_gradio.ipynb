# %% [raw]
# ---
# output-file: gradio.html
# title: Gradio tutorial with Hugging Face Spaces deployment
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Please reference [this blog post](https://nbdev.fast.ai/blog/posts/2022-11-07-spaces) on how to use this notebook.

# %% [markdown]
# ## Install dependencies

# %% [markdown]
# ## Make an app with Gradio

# %%
import gradio as gr
import time


def echo(message, history, system_prompt, tokens):
    response = f"System prompt: {system_prompt}\n Message: {message}."
    for i in range(min(len(response), int(tokens))):
        time.sleep(0.05)
        yield response[: i + 1]


with gr.Blocks() as demo:
    system_prompt = gr.Textbox("You are helpful AI.", label="System Prompt")
    slider = gr.Slider(10, 100, render=False)

    gr.ChatInterface(echo, additional_inputs=[system_prompt, slider], type="messages")

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
demo.close()

# %%
import gradio as gr
import time


def echo(message, history, system_prompt, tkns):
    response = f"System prompt: {system_prompt}\n Message: {message}."
    for i in range(min(len(response), int(tkns))):
        time.sleep(0.05)
        yield response[: i + 1]


demo = gr.ChatInterface(
    echo,
    type="messages",
    additional_inputs=[
        gr.Textbox("You are helpful AI.", label="System Prompt"),
        gr.Slider(10, 100, label="tk"),
    ],
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
demo.close()

# %%
import gradio as gr


def count_images(message, history):
    num_images = len(message["files"])
    total_images = 0
    for message in history:
        if isinstance(message["content"], tuple):
            total_images += 1
    return f"You just uploaded {num_images} images, total uploaded: {total_images + num_images}"


demo = gr.ChatInterface(
    fn=count_images,
    type="messages",
    examples=[{"text": "No files", "files": []}],
    multimodal=True,
    textbox=gr.MultimodalTextbox(
        file_count="multiple", file_types=["image"], sources=["upload", "microphone"]
    ),
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
demo.close()

# %%
import gradio as gr


def yes_man(message, history):
    if message.endswith("?"):
        return "Yes"
    else:
        return "Ask me anything!"


gr.ChatInterface(
    yes_man,
    type="messages",
    chatbot=gr.Chatbot(height=300),
    textbox=gr.Textbox(
        placeholder="Ask me a yes or no question", container=False, scale=7
    ),
    title="Yes Man",
    description="Ask Yes Man any question",
    theme="ocean",
    examples=["Hello", "Am I cool?", "Are tomatoes vegetables?"],
    cache_examples=True,
).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# Caching examples at: '/Users/x/devel/cell/ribosome/res/siasun_md_sample/SN024002/.gradio/cached_examples/72'
#
# To create a public link, set `share=True` in `launch()`.
# <ipython-input-1-44e28c783d50>:14: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot=gr.Chatbot(height=300),
# /Users/x/.pyenv/versions/miniconda3-3.12-25.1.1-2/envs/cell/lib/python3.12/site-packages/gradio/chat_interface.py:310: UserWarning: The type of the gr.Chatbot does not match the type of the gr.ChatInterface.The type of the gr.ChatInterface, 'messages', will be used.
#   warnings.warn(
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
demo.close()

# %%
#| echo: false
#| output: asis
show_doc(size)
# Out:
# ---
#
# ### size
#
# >      size (repo:str)
#
# *Returns the size in GB of a HuggingFace Dataset.*

# %%
# !echo $HF_ENDPOINT

# %%
size("tglcourse/CelebA-faces-cropped-128")

# %%
# this is only necessary in a notebook
iface.close()

# %% [markdown]
# ## Create a `requirements.txt` file

# %%
fastcore

# %% [markdown]
# ## Convert this notebook into a Gradio app

# %%
# from nbdev.export import nb_export
# nb_export('01_gradio.ipynb', lib_path='.', name='gradio')

# %% [markdown]
# <div>
# <link rel="stylesheet" href="https://gradio.s3-us-west-2.amazonaws.com/2.6.5/static/bundle.css">
# <div id="target"></div>
# <script src="https://gradio.s3-us-west-2.amazonaws.com/2.6.5/static/bundle.js"></script>
# <script>
# launchGradioFromSpaces("abidlabs/question-answering", "#target")
# </script>
# </div>
