# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # system.utils
#
# >DOM utils
# output-file: system.utils.html
# title: system.utils
#
# This notebook provides utility functions for system operations.
# ---

# %%
# | default_exp system.utils

# %%
# | export
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import Markdown, display
from nbdev.showdoc import *

shell = InteractiveShell.instance()
shell.ast_node_interactivity = "all"

# %%
#| export
from fastcore.basics import patch
from fastcore.test import *

# %%
# | export
from pathlib import Path
import subprocess

# %%
# | export
def get_project_root(start=None, markers=("pyproject.toml", ".git", "requirements.txt")) -> Path:
    current = Path(start or Path.cwd()).resolve()
    for path in [current, *current.parents]:
        if any((path / marker).exists() for marker in markers):
            return path
    raise FileNotFoundError("Could not find project root")

# %%
# | hide
project_root = get_project_root()
print(project_root)

# %%
# | export
def get_git_root() -> Path:
    try:
        root = subprocess.check_output(
            ["git", "rev-parse", "--show-toplevel"],
            text=True,
            stderr=subprocess.DEVNULL,
        ).strip()
        return Path(root)
    except subprocess.CalledProcessError:
        raise RuntimeError("Current notebook is not inside a Git repository")

# %%
# | hide
project_root = get_project_root()
print(project_root)

# %%
# | hide
import nbdev

nbdev.nbdev_export()
