# %% [markdown]
# # preprocessing.parsing.ms_office.markitdown.linux
#
# > Linux entry point for the shared MarkItDown Office workflow.

# %%
# |default_exp preprocessing.parsing.ms_office.markitdown.linux

# %%
# | hide
from nbdev.showdoc import *

# %% [markdown]
# ## Shared API
#
# The conversion, PPTX recovery, image extraction, and recursive workflow are platform-neutral and live in `preprocessing.parsing.ms_office.markitdown.utils`.

# %%
# | export
from ribosome.preprocessing.parsing.ms_office.markitdown import utils as _utils

DATA_IMAGE_RE = _utils.DATA_IMAGE_RE
DEFAULT_MAX_CONCURRENCY = _utils.DEFAULT_MAX_CONCURRENCY
ENV_FILE = _utils.ENV_FILE
OFFICE_EXTENSIONS = _utils.OFFICE_EXTENSIONS
PROJ_ROOT = _utils.PROJ_ROOT
convert_office_to_md = _utils.convert_office_to_md
extract_base64_from_md = _utils.extract_base64_from_md
extract_base64_images = _utils.extract_base64_images
get_office_files_root = _utils.get_office_files_root
process_office_files = _utils.process_office_files

# %% [markdown]
# ## Run on Linux
#
# The shared workflow runs Office conversions and image extraction concurrently. Set `MARKITDOWN_MAX_CONCURRENCY` before importing the module (default: `4`), or pass `max_concurrency` explicitly.

# %%
# | notest
# Run the complete recursive pipeline configured by PROJ_ROOT/.env.
OFFICE_FILES_ROOT = await get_office_files_root()
processing_report = await process_office_files(
    OFFICE_FILES_ROOT,
    overwrite=False,
    max_concurrency=DEFAULT_MAX_CONCURRENCY,
)

# %%
# | hide
# | notest
import nbdev

nbdev.nbdev_export()
