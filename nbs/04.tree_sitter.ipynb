# %%
from tree_sitter import Language

# %%
# This builds the compiled library (siasun.so or siasun.dll)
# 'tree-sitter-siasun' is the directory containing your grammar.js and src/parser.c
Language.build_library(
    # Output file name
    'siasun_robot.so',

    # List of directories containing the grammar.js
    [
        'tree-sitter-siasun'
    ]
)
