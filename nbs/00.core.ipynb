# %% [raw]
# ---
# description: Fill in a module description here
# output-file: core.html
# title: core
#
# ---

# %%
# | default_exp core

# %%
# | hide
from nbdev.showdoc import *

# %%
# | export
def foo():
    pass

# %%
# | hide
import nbdev

nbdev.nbdev_export()
