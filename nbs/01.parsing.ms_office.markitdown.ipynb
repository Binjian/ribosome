# %% [raw]
# ---
# output-file: parsing.ms_office_markitdown.html
# title: Microsoft Office document parsing with markitdown
# ---

# %%
# |default_exp parsing.ms_office.markitdown

# %%
# | hide
from nbdev.showdoc import *
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Install dependencies

# %%
# | export
import sys
import os
import time
from hashlib import sha256
from pathlib import Path, PurePosixPath
from pprint import pprint, pformat

from openai import OpenAI
from markitdown import MarkItDown
import subprocess
from pathlib import Path
import pandas as pd
import re
import base64
import os
import shutil
import uuid # For more unique filenames, or use a counter

# %%
#| export
from dotenv import load_dotenv
load_dotenv()
OPENROUTER_API_KEY= os.getenv('OPENROUTER_API_KEY')
print(OPENROUTER_API_KEY)
OPENROUTER_API_URL = os.getenv('OPENROUTER_API_URL')
print(OPENROUTER_API_URL)
OPENROUTER_MODEL = os.getenv('OPENROUTER_MODEL')
# OPENROUTER_MODEL = 'OpenAI:o3'
print(OPENROUTER_MODEL)
# Out:
# True
# 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
# https://openrouter.ai/api/v1
# Google:gemini-2.5-pro-exp-03-25

# %%
#| export
# Optionally, provide your LLM client and model for OCR fallback and default table detection
llm_client = OpenAI(
  base_url=f"{OPENROUTER_API_URL}",
  api_key=f"{OPENROUTER_API_KEY}",
)
llm_model = f"{OPENROUTER_MODEL}"

# %%
def convert_office_to_md(root_folder: Path | str, bOverwrite: bool = False, bUsePandas: bool = True, bUsePandoc: bool= False):
    """
    Recursively convert all .pptx, .ppt, .docx, and .doc files under
    root_folder (and subfolders) to PDF files in the same folder as the
    original. For .xls and .xlsx files, convert to markdown (.md) files
    in the same folder. Requires LibreOffice (soffice) installed for Office
    document conversion. Requires pandas for Excel to markdown.
    """

    office_exts = {'.pptx', '.ppt', '.docx', '.doc'}
    word_exts = {'.docx', '.doc'}
    ppt_exts = {'.pptx', '.ppt'}
    excel_exts = {'.xls', '.xlsx', '.csv', '.tsv', '.ods', '.xlsm', '.xlsb'}
    root = Path(root_folder)
    md_root = root / '.md'
    for file in root.rglob('*'):
        if file.suffix.lower() not in office_exts and file.suffix.lower() not in excel_exts:
            continue
        md_path = file.with_suffix('.md')
        md_path = md_root / md_path.relative_to(root)
        md_path = md_path.parent / md_path.stem /(md_path.stem + '.md')

        if not bOverwrite:
            if md_path.exists():
                continue  # Skip if md already exists
        if not md_path.parent.exists():
            md_path.parent.mkdir(parents=True, exist_ok=False)
        if file.suffix.lower() in ppt_exts:
            try:
                # Use markitdown for conversion
                subprocess.run([
                    'markitdown', str(file),
                    '-o', md_path, #str(file.parent / md_path), 
                    '--keep-data-uris',
                ], check=True)
                print(f"Converted: {file} -> {md_path}")
            except subprocess.CalledProcessError as e:
                print(f"Failed to convert {file}: {e}")
        if file.suffix.lower() in word_exts:
            if not bUsePandoc:
                try:
                    # Use markitdown for conversion
                    subprocess.run([
                        'markitdown', str(file),
                        '-o', md_path, #str(file.parent / md_path), 
                        '--keep-data-uris',
                    ], check=True)
                    print(f"Converted: {file} -> {md_path}")
                except subprocess.CalledProcessError as e:
                    print(f"Failed to convert {file}: {e}")
            else:
                try:
                    # Use markitdown for conversion
                    subprocess.run([
                        'pandoc', str(file),
                        '-t', 'gfm',
                        '-o', md_path, #str(file.parent / md_path), 
                        '--extract-media', str(md_path.parent),
                    ], check=True)
                    print(f"Converted: {file} -> {md_path}")
                except subprocess.CalledProcessError as e:
                    print(f"Failed to convert {file}: {e}")
        elif file.suffix.lower() in excel_exts:
            if bUsePandas:
                try:
                    excel = pd.read_excel(file, sheet_name=None)
                    with open(md_path, 'w', encoding='utf-8') as f:
                        for sheet, df in excel.items():
                            f.write(f'# Sheet: {sheet}\n\n')
                            f.write(df.to_markdown(index=False))
                            f.write('\n\n')
                    print(f"Converted: {file} -> {md_path}")
                except Exception as e:
                    print(f"Failed to convert {file} to markdown: {e}")
            else:
                try:
                    # Use markitdown for conversion
                    subprocess.run([
                        'markitdown', str(file),
                        '-o', md_path, #str(file.parent / md_path), 
                        '--keep-data-uris',
                    ], check=True)
                    print(f"Converted: {file} -> {md_path}")
                except subprocess.CalledProcessError as e:
                    print(f"Failed to convert {file}: {e}")
        elif file.suffix.lower() == '.pdf':
            pass 
        else:
            pass

# %%
if False:
    # convert_office_to_md(r'D:/E/downloads/新型机器人智能问答系统数据源-mid',bOverwrite=True, bUsePandas=False, bUsePandoc=True)
    convert_office_to_md('/v/data/新型机器人智能问答系统数据源-mid',bOverwrite=True, bUsePandas=False, bUsePandoc=True)
# convert_office_to_md('/v/data/新型机器人智能问答系统数据源-mid/09 工业机器人营销、售后支持话术指导书',bOverwrite=True, bUsePandas=False, bUsePandoc=True)
# convert_office_to_md('../res/test_cases',bOverwrite=False,bUsePandas=False)

# %%
#| export

def extract_base64_images(markdown_file_path, image_output_folder="."):
    """
    Extracts base64 embedded images from a Markdown file, saves them to a folder,
    and replaces the base64 strings with relative paths to the new image files.

    Args:
        markdown_file_path (str): Path to the input Markdown file.
        image_output_folder (str): Name of the folder to save extracted images.
                                   This folder will be created relative to the
                                   Markdown file's directory if it doesn't exist.
    """
    if not os.path.exists(markdown_file_path):
        print(f"Error: Markdown file not found at {markdown_file_path}")
        return
    # markdown_file_stem = markdown_file_path.stem
    markdown_dir = os.path.dirname(os.path.abspath(markdown_file_path))
    full_image_output_path = os.path.join(markdown_dir, image_output_folder)

    if not os.path.exists(full_image_output_path):
        os.makedirs(full_image_output_path)
        # print(f"Created image output folder: {full_image_output_path}")

    with open(markdown_file_path, 'r', encoding='utf-8') as f:
        content = f.read()

    # Regex to find base64 encoded images in Markdown
    # Pattern: ![alt text](..._STRING)
    # Groups:
    # 1: Alt text
    # 2: Image format (e.g., png, jpeg)
    # 3: Base64 data string
    # We also capture the full match (group 0) to replace it
    regex_img_quote = r"!\[(.*?)\]\(data:image/(.+?);base64,([A-Za-z0-9+/=\s]+)\)"
    regex_illegal_file_name = r'[^a-zA-Z0-9_\-\.]+'  # Legal characters for filenames

    new_content = content
    images_extracted_count = 0

    # We need to iterate carefully as string replacements change string length
    # Finding all matches first and then replacing is safer, but can be tricky
    # if matches overlap (not typical for this pattern).
    # A simpler approach for non-overlapping, distinct matches is to iterate
    # and replace. For more complex scenarios, one might work on a list of lines
    # or use re.sub with a function.

    # Using re.finditer to get match objects for more control
    for i, match in enumerate(re.finditer(regex_img_quote, content)):
        full_match_str = match.group(0)
        alt_text = match.group(1)
        # Normalize alt text to a legal filename
        alt_text = re.sub(regex_illegal_file_name, '_', alt_text)  # Replace illegal characters with '_'
        alt_text = alt_text.strip()  # Remove leading/trailing whitespace
        alt_text = alt_text[:50] if len(alt_text) > 50 else alt_text  # Limit length to 50 characters
        alt_text = 'img' if not alt_text else alt_text # If alt text is empty, use a default name

        image_format = match.group(2).lower() # e.g., png, jpeg
        image_format = re.sub(r'x-([a-zA-Z])', r'\1', image_format) # Normalize format (e.g., x-wmf/x-emf to wmf/emf)
        base64_data = match.group(3)

        # Clean up base64 data (remove potential whitespace)
        base64_data_cleaned = "".join(base64_data.split())
        # Fix missing padding
        missing_padding = len(base64_data_cleaned) % 4
        if missing_padding != 0:
            base64_data_cleaned += '=' * (4 - missing_padding)
        try:
            image_data = base64.b64decode(base64_data_cleaned)
        except base64.binascii.Error as e:
            print(f"Warning: Could not decode base64 string for an image (alt: {alt_text}). Error: {e}")
            continue # Skip this image

        # Generate a unique filename
        # Using a counter is simple, could use uuid for more robustness
        image_filename = f"{alt_text}_{images_extracted_count}.{image_format}"
        image_filepath = os.path.join(full_image_output_path, image_filename)

        # Save the image
        with open(image_filepath, 'wb') as img_file:
            img_file.write(image_data)
        # print(f"Extracted and saved: {image_filepath}")
        if image_format == 'wmf': # in case of wmf, we need to convert it to svg with soffice
            svg_file = Path(image_filepath).with_suffix('.svg') 
            subprocess.run([
                'soffice', '--headless', '--convert-to', 'svg',
                str(image_filepath),
                '--outdir', str(full_image_output_path),
            ], check=True)
            # if svg_file.exists():
            #     Path(image_filepath).unlink()  # Remove the original WMF file
                # image_filename = svg_file.name  # Update filename to the new SVG file

            png_file = Path(image_filepath).with_suffix('.png')
            subprocess.run([
                'soffice', '--headless', '--convert-to', 'png',
                str(image_filepath),
                '--outdir', str(full_image_output_path),
            ], check=True)
            if png_file.exists():
                # Path(image_filepath).unlink()  # Remove the original WMF file
                image_filename = png_file.name  # Update filename to the new SVG file
        elif image_format == 'emf': # in case of wmf, we need to convert it to svg with soffice
            svg_file = Path(image_filepath).with_suffix('.svg') 
            subprocess.run([
                'soffice', '--headless', '--convert-to', 'svg',
                str(image_filepath),
                '--outdir', str(full_image_output_path),
            ], check=True)
            png_file = Path(image_filepath).with_suffix('.png')
            subprocess.run([
                'soffice', '--headless', '--convert-to', 'png',
                str(image_filepath),
                '--outdir', str(full_image_output_path),
            ], check=True)
            if png_file.exists():
                # Path(image_filepath).unlink()  # Remove the original WMF file
                image_filename = png_file.name  # Update filename to the new SVG file
        # Create the new Markdown image link (relative path)
        # The path in Markdown should be relative to the Markdown file itself
        relative_image_path = os.path.join(image_output_folder, image_filename)
        # Ensure forward slashes for Markdown paths, even on Windows
        relative_image_path_markdown = relative_image_path.replace(os.sep, '/')
        new_image_md_link = f"![{alt_text}]({relative_image_path_markdown})"

        # Replace the original base64 string with the new link in the `new_content`
        # Only replace the first occurrence of this specific full_match_str in case of duplicates
        # (though each match from finditer is unique in its position)
        new_content = new_content.replace(full_match_str, new_image_md_link, 1)
        images_extracted_count += 1

    if images_extracted_count > 0:
        # Save the modified Markdown content
        # You might want to save to a new file, e.g., original_filename_modified.md
        # For this example, I'll overwrite the original. Be careful!
        # Consider backing up your original file first.
        output_markdown_file_path = markdown_file_path # Overwrite
        # output_markdown_file_path = os.path.splitext(markdown_file_path)[0] + "_modified.md" # New file

        with open(output_markdown_file_path, 'w', encoding='utf-8') as f:
            f.write(new_content)
        print(f"Modified Markdown saved to: {output_markdown_file_path}, processed {images_extracted_count} image(s).")
    else:
        print("No base64 embedded images found in the Markdown file.")

# %%
#| export
def extract_md_base64_images_win(markdown_file_path, image_output_folder=".") -> int:
    """
    Extracts base64 embedded images from a Markdown file, saves them to a folder,
    and replaces the base64 strings with relative paths to the new image files.
    This version is tailored for Windows environments, ensuring compatibility
    with Windows file paths and handling of WMF/EMF images using ImageMagick 'magick' command.

    Args:
        markdown_file_path (str): Path to the input Markdown file.
        image_output_folder (str): Name of the folder to save extracted images.
                                   This folder will be created relative to the
                                   Markdown file's directory if it doesn't exist.
    """
    if not os.path.exists(markdown_file_path):
        print(f"Error: Markdown file not found at {markdown_file_path}")
        return -1
    # markdown_file_stem = markdown_file_path.stem
    markdown_dir = os.path.dirname(os.path.abspath(markdown_file_path))
    full_image_output_path = os.path.join(markdown_dir, image_output_folder)

    if not os.path.exists(full_image_output_path):
        os.makedirs(full_image_output_path)
        # print(f"Created image output folder: {full_image_output_path}")

    with open(markdown_file_path, 'r', encoding='utf-8') as f:
        content = f.read()

    # Regex to find base64 encoded images in Markdown
    # Pattern: ![alt text](..._STRING)
    # Groups:
    # 1: Alt text
    # 2: Image format (e.g., png, jpeg)
    # 3: Base64 data string
    # We also capture the full match (group 0) to replace it
    regex_md_img_quote = r"!\[(.*?)\]\(data:image/(.+?);base64,([A-Za-z0-9+/=\s]+)\)"
    regex_illegal_file_name = r'[^a-zA-Z0-9_\-\.]+'  # Legal characters for filenames

    first_match = re.search(regex_md_img_quote, content)
    if not first_match:
        return -1
    new_content = content
    images_extracted_count = 0

    # We need to iterate carefully as string replacements change string length
    # Finding all matches first and then replacing is safer, but can be tricky
    # if matches overlap (not typical for this pattern).
    # A simpler approach for non-overlapping, distinct matches is to iterate
    # and replace. For more complex scenarios, one might work on a list of lines
    # or use re.sub with a function.

    # Using re.finditer to get match objects for more control
    for i, match in enumerate(re.finditer(regex_md_img_quote, content)):
        full_match_str = match.group(0)
        alt_text = match.group(1)
        # Normalize alt text to a legal filename
        alt_text = re.sub(regex_illegal_file_name, '_', alt_text)  # Replace illegal characters with '_'
        alt_text = alt_text.strip()  # Remove leading/trailing whitespace
        alt_text = alt_text[:50] if len(alt_text) > 50 else alt_text  # Limit length to 50 characters
        alt_text = 'img' if not alt_text else alt_text # If alt text is empty, use a default name

        image_format = match.group(2).lower() # e.g., png, jpeg
        image_format = re.sub(r'x-([a-zA-Z])', r'\1', image_format) # Normalize format (e.g., x-wmf/x-emf to wmf/emf)
        base64_data = match.group(3)

        # Clean up base64 data (remove potential whitespace)
        base64_data_cleaned = "".join(base64_data.split())
        # Fix missing padding
        missing_padding = len(base64_data_cleaned) % 4
        if missing_padding != 0:
            base64_data_cleaned += '=' * (4 - missing_padding)
        try:
            image_data = base64.b64decode(base64_data_cleaned)
        except base64.binascii.Error as e:
            print(f"Warning: Could not decode base64 string for an image (alt: {alt_text}). Error: {e}")
            continue # Skip this image

        # Generate a unique filename
        # Using a counter is simple, could use uuid for more robustness
        image_filename = f"{alt_text}_{images_extracted_count}.{image_format}"
        image_filepath = os.path.join(full_image_output_path, image_filename)

        # Save the image
        with open(image_filepath, 'wb') as img_file:
            img_file.write(image_data)
        # print(f"Extracted and saved: {image_filepath}")
        if image_format == 'wmf': # in case of wmf, we need to convert it to svg with soffice
            svg_file = Path(image_filepath).with_suffix('.svg') 
            subprocess.run([
                'magick', '-units', 'PixelsPerInch',
                str(image_filepath),
                '-density', '300',
                '-trim', '-border', '5',
                str(svg_file),
            ], check=True)
            png_file = Path(image_filepath).with_suffix('.png')
            subprocess.run([
                'magick', '-units', 'PixelsPerInch',
                str(image_filepath),
                '-density', '300',
                '-trim', '-border', '5',
                str(png_file),
            ], check=True)
            if png_file.exists():
                # Path(image_filepath).unlink()  # Remove the original WMF file
                image_filename = png_file.name  # Update filename to the new SVG file
        if image_format == 'emf': # in case of wmf, we need to convert it to svg with soffice
            svg_file = Path(image_filepath).with_suffix('.svg') 
            subprocess.run([
                'magick', '-units', 'PixelsPerInch',
                str(image_filepath),
                '-density', '300',
                '-trim', '-border', '5',
                str(svg_file),
            ], check=True)
            png_file = Path(image_filepath).with_suffix('.png')
            subprocess.run([
                'magick', '-units', 'PixelsPerInch',
                str(image_filepath),
                '-density', '300',
                '-trim', '-border', '5',
                str(png_file),
            ], check=True)
            if png_file.exists():
                # Path(image_filepath).unlink()  # Remove the original WMF file
                image_filename = png_file.name  # Update filename to the new SVG file
        # Create the new Markdown image link (relative path)
        # The path in Markdown should be relative to the Markdown file itself
        relative_image_path = os.path.join(image_output_folder, image_filename)
        # Ensure forward slashes for Markdown paths, even on Windows
        relative_image_path_markdown = relative_image_path.replace(os.sep, '/')
        new_image_md_link = f"![{alt_text}]({relative_image_path_markdown})"

        # Replace the original base64 string with the new link in the `new_content`
        # Only replace the first occurrence of this specific full_match_str in case of duplicates
        # (though each match from finditer is unique in its position)
        new_content = new_content.replace(full_match_str, new_image_md_link, 1)
        images_extracted_count += 1

    if images_extracted_count > 0:
        # Save the modified Markdown content
        # You might want to save to a new file, e.g., original_filename_modified.md
        # For this example, I'll overwrite the original. Be careful!
        # Consider backing up your original file first.
        output_markdown_file_path = markdown_file_path # Overwrite
        # output_markdown_file_path = os.path.splitext(markdown_file_path)[0] + "_modified.md" # New file

        with open(output_markdown_file_path, 'w', encoding='utf-8') as f:
            f.write(new_content)

    return images_extracted_count

# %%
#| export
def extract_md_html_images_win(markdown_file_path) -> int:
    """
    Extracts base64 embedded images from a Markdown file, saves them to a folder,
    and replaces the base64 strings with relative paths to the new image files.
    This version is tailored for Windows environments, ensuring compatibility
    with Windows file paths and handling of WMF/EMF images using ImageMagick 'magick' command.

    Args:
        markdown_file_path (str): Path to the input Markdown file.
        image_output_folder (str): Name of the folder to save extracted images.
                                This folder will be created relative to the
                                Markdown file's directory if it doesn't exist.
    """
    if not os.path.exists(markdown_file_path):
        # print(f"Error: Markdown file not found at {markdown_file_path}")
        return -1

    with open(markdown_file_path, 'r', encoding='utf-8') as f:
        content = f.read()

    # Regex to find base64 encoded images in Markdown
    # Pattern: ![alt text](..._STRING)
    # Groups:
    # 1: Alt text
    # 2: Image format (e.g., png, jpeg)
    # 3: Base64 data string
    # We also capture the full match (group 0) to replace it
    # regex_md_img_quote = r"!\[(.*?)\]\(data:image/(.+?);base64,([A-Za-z0-9+/=\s]+)\)"
    # regex_html_img_quote = r'<img[^>]*src\s*=\s*["\']([^"\']+)["\'][^>]*>'  # Matches HTML img tags with src attributes
    regex_html_img_quote = r'<img[^>]*src\s*=\s*["\']([^"\']+/(media/.+\.([a-z]{3,4})))["\'][^>]*>'  # Matches HTML img tags with src attributes
    # regex_illegal_file_name = r'[^a-zA-Z0-9_\-\.]+'  # Legal characters for filenames

    first_match = re.search(regex_html_img_quote, content)
    if not first_match:
        return -1

    new_content = content
    images_extracted_count = 0

    # We need to iterate carefully as string replacements change string length
    # Finding all matches first and then replacing is safer, but can be tricky
    # if matches overlap (not typical for this pattern).
    # A simpler approach for non-overlapping, distinct matches is to iterate
    # and replace. For more complex scenarios, one might work on a list of lines
    # or use re.sub with a function.

    # Using re.finditer to get match objects for more control
    png_file_path = svg_file_path = None
    for i, match in enumerate(re.finditer(regex_html_img_quote, content)):
        # full_match_str = match.group(0)
        # Extract the file path and suffix from the match
        absolute_file_path = match.group(1)  # e.g., /absolute/path/to/media/image.png
        relative_file_path = Path('./' + match.group(2))  # e.g., ./media/image.png
        local_file_path = Path(markdown_file_path).parent / relative_file_path  # e.g., /path/to/markdown/media/image.png
        file_suffix = match.group(3)

        # print(f"Extracted and saved: {image_filepath}")
        if file_suffix == 'wmf': # in case of wmf, we need to convert it to svg with soffice
            svg_file_path = local_file_path.with_suffix('.svg') 
            subprocess.run([
                'magick', '-units', 'PixelsPerInch',
                str(local_file_path),
                '-density', '300',
                '-trim', '-border', '5',
                str(svg_file_path),
            ], check=True)
            png_file_path = local_file_path.with_suffix('.png')
            relative_file_path = relative_file_path.with_suffix('.png')  # Update relative path to png
            subprocess.run([
                'magick', '-units', 'PixelsPerInch',
                str(local_file_path),
                '-density', '300',
                '-trim', '-border', '5',
                str(png_file_path),
            ], check=True)
        elif file_suffix == 'emf': # in case of wmf, we need to convert it to svg with soffice
            svg_file_path = local_file_path.with_suffix('.svg') 
            subprocess.run([
                'magick', '-units', 'PixelsPerInch',
                str(local_file_path),
                '-density', '300',
                '-trim', '-border', '5',
                str(svg_file_path),
            ], check=True)
            png_file_path = local_file_path.with_suffix('.png')
            relative_file_path = relative_file_path.with_suffix('.png')  # Update relative path to png
            subprocess.run([
                'magick', '-units', 'PixelsPerInch',
                str(local_file_path),
                '-density', '300',
                '-trim', '-border', '5',
                str(png_file_path),
            ], check=True)

        # Replace the original base64 string with the new link in the `new_content`
        # Only replace the first occurrence of this specific full_match_str in case of duplicates
        # (though each match from finditer is unique in its position)
        if png_file_path or svg_file_path:
            images_extracted_count += 1
        
        new_file_path = PurePosixPath(relative_file_path)
        
        new_content = new_content.replace(absolute_file_path, str(new_file_path), 1)  # replace wmf/emf absolute file path with the new png/svg relative file path if exists

    # if images_extracted_count == 0:
    #     return print("No wmf or emf image found in the Markdown file.")
    # output_markdown_file_path = markdown_file_path # Overwrite
    # output_markdown_file_path = os.path.splitext(markdown_file_path)[0] + "_modified.md" # New file

    with open(markdown_file_path, 'w', encoding='utf-8') as f:  # Overwrite the original file
        f.write(new_content)
    # print(f"Modified Markdown saved to: {output_markdown_file_path}, processed {images_extracted_count} image(s).")
    return images_extracted_count



# extract_md_html_images_win('../res/SX022001《新松机器人安全手册》-V1.9/SX022001《新松机器人安全手册》-V1.9.md')

# %%
# --- How to use it ---
if False:
    # Create a dummy Markdown file for testing
    dummy_md_content = """
# My Document

This is some text.

Here is an image: A red dot

Some more text.

And another one: ![A blue square](data:image/jpeg;base64,...)

This one is tricky with potential newlines in base64:
With Newlines

End of document.
    """
    test_md_file = "test_document.md"
    with open(test_md_file, "w", encoding="utf-8") as f:
        f.write(dummy_md_content)
    print(f"Created dummy Markdown file: {test_md_file}")

    # Specify the path to your Markdown file
    markdown_file = test_md_file  # Or "your_actual_file.md"
    # Specify the folder (relative to the MD file) where images will be saved
    image_folder = "md_images"

    extract_base64_images(markdown_file, image_folder)

    # --- Optional: Clean up dummy files and folder after testing ---
    print("\nCleaning up dummy files...")
    if os.path.exists(os.path.join(os.path.dirname(test_md_file), image_folder)):
        for img_file in os.listdir(os.path.join(os.path.dirname(test_md_file), image_folder)):
            os.remove(os.path.join(os.path.dirname(test_md_file), image_folder, img_file))
        os.rmdir(os.path.join(os.path.dirname(test_md_file), image_folder))
    if os.path.exists(test_md_file):
        os.remove(test_md_file)
    print("Cleanup complete.")

# %%
#| export
def convert_html_wmf_emf_image_from_md(root_folder):
    """
    Recursively convert all .md files under
    root_folder (and subfolders) and extract all base64 images in them into
    a separate folder and replace the base64 image references in the markdown
    files with the path to the extracted image.
    """


    root = Path(root_folder)
    for file in root.rglob('*'):
        if file.suffix.lower() == '.md':
            try:
                # Create a folder with the file name and move the md file into it
                # Use replace original md file with base64 extracted in separate image folder
                res = extract_md_html_images_win(file)
                if res == -1:
                    print(f"Not Converted: {file}")
                else:
                    print(f'Converted {res} images in {file}')
                # file.unlink()  # Remove the original md file after extraction
            except subprocess.CalledProcessError as e:
                print(f"Failed to convert {file}: {e}")
    

# convert_html_wmf_emf_image_from_md(r'D:/E/downloads/新型机器人智能问答系统数据源-mid/md')

# %%
#| export
def extract_base64_from_md(root_folder):
    """
    Recursively convert all .md files under
    root_folder (and subfolders) and extract all base64 images in them into
    a separate folder and replace the base64 image references in the markdown
    files with the path to the extracted image.
    """


    root = Path(root_folder)
    # tmp = Path(root_folder).parent / 'tmp'
    # shutil.move(root, tmp) # Copy the whole folder to res
    # os.makedirs(root, exist_ok=False)  # make sure the root folder exists and is empty
    image_folder = "img"
    for file in root.rglob('*'):
        if file.suffix.lower() == '.md':
            try:
                # Create a folder with the file name and move the md file into it
                md_folder = file.parent  # / (file.stem)
                # res_folder = root / md_folder.relative_to(tmp)
                # shutil.copy(md_folder, res_folder)
                # new_md_file = res_folder / file.name
                # Use replace original md file with base64 extracted in separate image folder
                res = extract_md_base64_images_win(file,image_folder)
                if res == -1:
                    print(f"Not Converted: {file}")
                else:
                    print(f'Converted {res} images in {file}')
                # file.unlink()  # Remove the original md file after extraction
            except subprocess.CalledProcessError as e:
                print(f"Failed to convert {file}: {e}")
    
    # shutil.rmtree(tmp)  # Remove the temporary folder after extraction

# %%
# extract_base64_from_md(r'D:/E/downloads/新型机器人智能问答系统数据源-mid/md')

# %%
#| export
def copy_md_files(src_md_root: Path, dst_md_root: Path, bOverwrite: bool = True):
    """
    Recursively copy all .md files under
    src_md_folder (higher quality of original office converted md by MID) (and subfolders) 
    to dst_md_folder (low quality of original pdf converted md by gemini 2.5 pro exp).
    """

    # Create the destination folder if it does not exist
    if not dst_md_root.exists():
        dst_md_root.mkdir(parents=True, exist_ok=False)
    for file in src_md_root.rglob('*'):
        if file.suffix.lower() == '.md':
            try:
                # Create a folder with the file name and move the md file into it
                src_md_folder = file.parent
                dst_md_folder = dst_md_root / src_md_folder.relative_to(src_md_root) 
                if dst_md_folder.exists():
                    if bOverwrite:
                        shutil.rmtree(dst_md_folder)
                        print(f"Remove: {dst_md_folder}")
                    else:
                        print(f"Skipped: {dst_md_folder}")
                        continue
                shutil.copytree(src_md_folder, dst_md_folder)
                print(f"Copied: {src_md_folder} -> {dst_md_folder}")
            except subprocess.CalledProcessError as e:
                print(f"Failed to convert {file}: {e}")

# %%
copy_md_files(Path('/v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images'), Path('/v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl'))
# Out:
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024009《新松SR25A-35-1.80规格参数》A-2
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024009《新松SR25A-35-1.80规格参数》A-2 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024009《新松SR25A-35-1.80规格参数》A-2
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024001《新松SR12A-12-1.46规格参数》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024001《新松SR12A-12-1.46规格参数》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024001《新松SR12A-12-1.46规格参数》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SN024003《新松SN4A-4-0.58规格参数》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SN024003《新松SN4A-4-0.58规格参数》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SN024003《新松SN4A-4-0.58规格参数》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024012《新松SR210-120-3.05规格参数》A-2
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024012《新松SR210-120-3.05规格参数》A-2 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024012《新松SR210-120-3.05规格参数》A-2
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024007《新松SR50A-50-2.15规格参数》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024007《新松SR50A-50-2.15规格参数》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024007《新松SR50A-50-2.15规格参数》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024003《新松SR25A-12-2.01规格参数》A-2
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024003《新松SR25A-12-2.01规格参数》A-2 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024003《新松SR25A-12-2.01规格参数》A-2
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024004《新松SR210A-210-2.65规格参数》A-2
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024004《新松SR210A-210-2.65规格参数》A-2 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024004《新松SR210A-210-2.65规格参数》A-2
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SP024001《新松SP120A-120-2.50规格参数》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SP024001《新松SP120A-120-2.50规格参数》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SP024001《新松SP120A-120-2.50规格参数》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024006《新松SR500A-360-2.83规格参数》A-2
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024006《新松SR500A-360-2.83规格参数》A-2 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024006《新松SR500A-360-2.83规格参数》A-2
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024008《新松SR25A-25-1.80规格参数》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024008《新松SR25A-25-1.80规格参数》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024008《新松SR25A-25-1.80规格参数》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SX024001《新松通用外部轴 规格参数》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SX024001《新松通用外部轴 规格参数》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SX024001《新松通用外部轴 规格参数》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR02400101《Siasun SR12A-12-1.46 Specifications-CE》A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR02400101《Siasun SR12A-12-1.46 Specifications-CE》A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR02400101《Siasun SR12A-12-1.46 Specifications-CE》A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024002《新松SR25A-20-1.80规格参数》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024002《新松SR25A-20-1.80规格参数》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024002《新松SR25A-20-1.80规格参数》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR02400301《Siasun SR25A-12-2.01 Specifications-CE》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR02400301《Siasun SR25A-12-2.01 Specifications-CE》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR02400301《Siasun SR25A-12-2.01 Specifications-CE》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024010《新松SR500A-500-2.52规格参数》A-2
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024010《新松SR500A-500-2.52规格参数》A-2 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024010《新松SR500A-500-2.52规格参数》A-2
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR02400401《 SIASUN SR210A-210-2.65规格参数-CE》A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR02400401《 SIASUN SR210A-210-2.65规格参数-CE》A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR02400401《 SIASUN SR210A-210-2.65规格参数-CE》A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024013《新松SR270A-270-2.70规格参数》A-4
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024013《新松SR270A-270-2.70规格参数》A-4 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024013《新松SR270A-270-2.70规格参数》A-4
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024005《新松SR210A-210-3.05-DW规格参数》A-2
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024005《新松SR210A-210-3.05-DW规格参数》A-2 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024005《新松SR210A-210-3.05-DW规格参数》A-2
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024011《新松SR50A-70-2.15规格参数》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SR024011《新松SR50A-70-2.15规格参数》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SR024011《新松SR50A-70-2.15规格参数》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SN024002《新松SN7B-7-0.90规格参数》A-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/05 技术规格/规格参数/SN024002《新松SN7B-7-0.90规格参数》A-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/05 技术规格/规格参数/SN024002《新松SN7B-7-0.90规格参数》A-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/01 设计标准/新松机器人产品识别设计标准（推荐） 250219
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/01 设计标准/新松机器人产品识别设计标准（推荐） 250219 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/01 设计标准/新松机器人产品识别设计标准（推荐） 250219
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SX023012汽车行业解决方案介绍-A_1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/02 产品推介资料/SX023012汽车行业解决方案介绍-A_1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SX023012汽车行业解决方案介绍-A_1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SX023011新松工业机器人宣传（产品篇）-A_0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/02 产品推介资料/SX023011新松工业机器人宣传（产品篇）-A_0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SX023011新松工业机器人宣传（产品篇）-A_0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SX023010新松打磨解决方案介绍V1.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/02 产品推介资料/SX023010新松打磨解决方案介绍V1.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SX023010新松打磨解决方案介绍V1.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/20241112新松工业机器人宣传（案例版）
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/02 产品推介资料/20241112新松工业机器人宣传（案例版） -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/20241112新松工业机器人宣传（案例版）
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SIASUN industrial robot BG Introduction(0241018压缩版）
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/02 产品推介资料/SIASUN industrial robot BG Introduction(0241018压缩版） -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SIASUN industrial robot BG Introduction(0241018压缩版）
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SR023001新松电动车车架焊接解决方案介绍V1.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/02 产品推介资料/SR023001新松电动车车架焊接解决方案介绍V1.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/02 产品推介资料/SR023001新松电动车车架焊接解决方案介绍V1.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/09 工业机器人营销、售后支持话术指导书/SIASUN新松工业机器人营销、售后支持话术指导书_V3.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/09 工业机器人营销、售后支持话术指导书/SIASUN新松工业机器人营销、售后支持话术指导书_V3.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/09 工业机器人营销、售后支持话术指导书/SIASUN新松工业机器人营销、售后支持话术指导书_V3.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/07 机器人产品配置清单/SIASUN机器人产品配置清单_v25.2.28
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/07 机器人产品配置清单/SIASUN机器人产品配置清单_v25.2.28 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/07 机器人产品配置清单/SIASUN机器人产品配置清单_v25.2.28
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/技术规格/SX324001《新松机器人免示教焊接系统应用范围说明》-V1.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/技术规格/SX324001《新松机器人免示教焊接系统应用范围说明》-V1.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/技术规格/SX324001《新松机器人免示教焊接系统应用范围说明》-V1.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V3.0版本/SX322005《新松机器人视觉应用操作手册》-V1.0  -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V3.0版本/SX322005《新松机器人视觉应用操作手册》-V1.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V3.0版本/SX322010《新松机器人负载分析软件使用手册》-V1.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V3.0版本/SX322010《新松机器人负载分析软件使用手册》-V1.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V3.0版本/SX322010《新松机器人负载分析软件使用手册》-V1.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V3.0版本/SX322009《新松机器人离线接口库使用手册》-V1.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V3.0版本/SX322009《新松机器人离线接口库使用手册》-V1.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V3.0版本/SX322009《新松机器人离线接口库使用手册》-V1.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V3.0版本/SX322008《新松机器人免示教焊接软件操作手册》-V1.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V3.0版本/SX322008《新松机器人免示教焊接软件操作手册》-V1.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V3.0版本/SX322008《新松机器人免示教焊接软件操作手册》-V1.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V3.0版本/SX322001《新松机器人通用操作手册》-V1.4
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V3.0版本/SX322001《新松机器人通用操作手册》-V1.4 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V3.0版本/SX322001《新松机器人通用操作手册》-V1.4
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322003《新松机器人弧焊应用操作手册》-V1.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322003《新松机器人弧焊应用操作手册》-V1.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322003《新松机器人弧焊应用操作手册》-V1.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322011《新松机器人搬运应用操作手册》-A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322011《新松机器人搬运应用操作手册》-A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322011《新松机器人搬运应用操作手册》-A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322006新松机器人打磨应用操作手册（A-1)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322006新松机器人打磨应用操作手册（A-1) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322006新松机器人打磨应用操作手册（A-1)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322014《新松机器人SPR铆接功能使用手册》-A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322014《新松机器人SPR铆接功能使用手册》-A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322014《新松机器人SPR铆接功能使用手册》-A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322013《新松机器人螺柱焊功能使用手册》-A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322013《新松机器人螺柱焊功能使用手册》-A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322013《新松机器人螺柱焊功能使用手册》-A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322003《新松机器人弧焊应用操作手册》(B-2)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322003《新松机器人弧焊应用操作手册》(B-2) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322003《新松机器人弧焊应用操作手册》(B-2)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322007《新松机器人点焊应用操作手册》-A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322007《新松机器人点焊应用操作手册》-A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322007《新松机器人点焊应用操作手册》-A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322009《新松机器人离线接口库使用手册》(B-4)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322009《新松机器人离线接口库使用手册》(B-4) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322009《新松机器人离线接口库使用手册》(B-4)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322015《新松机器人快换应用操作手册》-A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322015《新松机器人快换应用操作手册》-A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322015《新松机器人快换应用操作手册》-A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322004《新松机器人激光焊应用操作手册》-A-3
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322004《新松机器人激光焊应用操作手册》-A-3 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322004《新松机器人激光焊应用操作手册》-A-3
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322016《新松机器人FDS应用使用手册》-A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322016《新松机器人FDS应用使用手册》-A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322016《新松机器人FDS应用使用手册》-A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322012《新松机器人涂胶功能使用手册》-A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322012《新松机器人涂胶功能使用手册》-A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322012《新松机器人涂胶功能使用手册》-A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322005《新松机器人视觉应用操作手册》（A-1)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322005《新松机器人视觉应用操作手册》（A-1) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322005《新松机器人视觉应用操作手册》（A-1)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322017《新松机器人跟随应用操作手册》-A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322017《新松机器人跟随应用操作手册》-A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322017《新松机器人跟随应用操作手册》-A-0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322001《新松机器人通用操作手册》（B-2)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322001《新松机器人通用操作手册》（B-2) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322001《新松机器人通用操作手册》（B-2)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322002《新松机器人码垛应用操作手册》-V1.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/软件类/手册/V4.0版本/SX322002《新松机器人码垛应用操作手册》-V1.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/软件类/手册/V4.0版本/SX322002《新松机器人码垛应用操作手册》-V1.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/快速安装类/SN022001《新松 SN系列工业机器人快速安装手册》- V1.1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/快速安装类/SN022001《新松 SN系列工业机器人快速安装手册》- V1.1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/快速安装类/SN022001《新松 SN系列工业机器人快速安装手册》- V1.1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/快速安装类/SR022001《新松 SR系列工业机器人快速安装手册》- V1.1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/快速安装类/SR022001《新松 SR系列工业机器人快速安装手册》- V1.1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/快速安装类/SR022001《新松 SR系列工业机器人快速安装手册》- V1.1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/安全类/SX022001-Siasun Robot Safety Manual-V1.3
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/安全类/SX022001-Siasun Robot Safety Manual-V1.3 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/安全类/SX022001-Siasun Robot Safety Manual-V1.3
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/安全类/SX022001《新松机器人安全手册》-V1.9
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/安全类/SX022001《新松机器人安全手册》-V1.9 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/安全类/SX022001《新松机器人安全手册》-V1.9
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122002新松SR25系列工业机器人安装及维护手册（A-6)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SR122002新松SR25系列工业机器人安装及维护手册（A-6) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122002新松SR25系列工业机器人安装及维护手册（A-6)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122001新松SR12系列工业机器人安装及维护手册（A-4)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SR122001新松SR12系列工业机器人安装及维护手册（A-4) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122001新松SR12系列工业机器人安装及维护手册（A-4)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SN122002新松SN4系列工业机器人安装及维护手册（A-2)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SN122002新松SN4系列工业机器人安装及维护手册（A-2) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SN122002新松SN4系列工业机器人安装及维护手册（A-2)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122003Installation and Maintenance Manual of Siasun SR210 Series Industrial Robot-A.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SR122003Installation and Maintenance Manual of Siasun SR210 Series Industrial Robot-A.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122003Installation and Maintenance Manual of Siasun SR210 Series Industrial Robot-A.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122003新松SR210系列工业机器人安装及维护手册（A-4)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SR122003新松SR210系列工业机器人安装及维护手册（A-4) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122003新松SR210系列工业机器人安装及维护手册（A-4)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122006新松SR50系列工业机器人安装及维护手册（A-3)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SR122006新松SR50系列工业机器人安装及维护手册（A-3) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122006新松SR50系列工业机器人安装及维护手册（A-3)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122004新松SR500系列工业机器人安装及维护手册（A-2)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SR122004新松SR500系列工业机器人安装及维护手册（A-2) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122004新松SR500系列工业机器人安装及维护手册（A-2)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SN122001新松SN7系列工业机器人安装及维护手册（A-5)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SN122001新松SN7系列工业机器人安装及维护手册（A-5) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SN122001新松SN7系列工业机器人安装及维护手册（A-5)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122002Installation and Maintenance Manual of Siasun SR25 Series Industrial Robot-A.1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SR122002Installation and Maintenance Manual of Siasun SR25 Series Industrial Robot-A.1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122002Installation and Maintenance Manual of Siasun SR25 Series Industrial Robot-A.1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SP122001新松SP120系列工业机器人安装及维护手册（A-0)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SP122001新松SP120系列工业机器人安装及维护手册（A-0) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SP122001新松SP120系列工业机器人安装及维护手册（A-0)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122005新松SR270系列工业机器人安装及维护手册（A-3)
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SR122005新松SR270系列工业机器人安装及维护手册（A-3) -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122005新松SR270系列工业机器人安装及维护手册（A-3)
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122001Installation and Maintenance Manual of Siasun SR12 Series Industrial Robot-A.0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/机械类/SR122001Installation and Maintenance Manual of Siasun SR12 Series Industrial Robot-A.0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/机械类/SR122001Installation and Maintenance Manual of Siasun SR12 Series Industrial Robot-A.0
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/电气类/SX222001《新松机器人电气使用及维护手册》-B-1
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/电气类/SX222001《新松机器人电气使用及维护手册》-B-1 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/电气类/SX222001《新松机器人电气使用及维护手册》-B-1
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/电气类/SX222002《新松机器人外部轴使用手册》-V1.4
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/电气类/SX222002《新松机器人外部轴使用手册》-V1.4 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/电气类/SX222002《新松机器人外部轴使用手册》-V1.4
# Remove: /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/电气类/SX222001Siasun Robot Electrical Operation and Maintenance Manual-A-0
# Copied: /v/data/新型机器人智能问答系统数据源-mid/.md.pandoc.raw.images/06 产品手册/电气类/SX222001Siasun Robot Electrical Operation and Maintenance Manual-A-0 -> /v/data/新型机器人智能问答系统数据源-md/.md.pandoc.hrsl/06 产品手册/电气类/SX222001Siasun Robot Electrical Operation and Maintenance Manual-A-0

# %%
#| export
# mid = MarkItDown(
#     enable_plugins=True,     # Mandatory
#     llm_client=llm_client,  # Mandatory
#     llm_model=llm_model,    # Mandatory
#     show_progress=True,  # Optional, defaults to False
#     ocr_service=None,  # Optional, defaults to "openrouter"k
#     table_detection_service=None,  # Optional, defaults to "openrouter":w
# )
mid = MarkItDown(
    llm_client=llm_client,  # Mandatory
    llm_model=llm_model,    # Mandatory
    show_progress=True,  # Optional, defaults to False
)

# %%
def convert_all_to_markdown_with_llm(root_folder: str | Path, mid: MarkItDown):
    """
    Recursively convert all .pdf files under root_folder (and subfolders)
    to markdown (.md) files in the same folder using marker-pdf's 'marker' command
    with 4 workers.
    """
    import subprocess
    from pathlib import Path
    # import os

    root = Path(root_folder)
    for file in root.rglob('*'):
        md_path = file.with_suffix('.md')
        if md_path.exists():
            continue  # Skip if markdown already exists
        try:
            result = mid.convert(
                file,
                show_progress=True,  # Show progress bar
                force_ocr=True,
                pages=None,  # Convert all pages
            )
            with open(md_path, 'w', encoding='utf-8') as f:
                f.write(result.markdown)
            print(f"Converted: {file} -> {md_path}")
        except subprocess.CalledProcessError as e:
            print(f"Failed to convert {file}: {e}")

# %%
convert_all_to_markdown_with_llm('/v/data/新型机器人智能问答系统数据源-merged-MID',mid)

# %%
import pdftotext

# %%
def convert_pdf_to_markdown_pdf2text(root_folder: str | Path):
    """
    Recursively convert all .pdf files under root_folder (and subfolders)
    to markdown (.md) files in the same folder using marker-pdf's 'marker' command
    with 4 workers.
    """
    import subprocess
    from pathlib import Path
    import pdftotext
    # import os

    root = Path(root_folder)
    for file in root.rglob('*.pdf'):
        md_path = file.with_suffix('.md')
        if md_path.exists():
            continue  # Skip if markdown already exists
        with open(file, "rb") as f:
            pdf = pdftotext.PDF(f)
        
        # Join all text from the PDF pages
        text = "\n\n".join(pdf)
        with open(md_path, 'w', encoding='utf-8') as f:
            f.write(text)
        print(f"Converted: {file} -> {md_path}")

# %%
convert_pdf_to_markdown_pdf2text('/v/data/新型机器人智能问答系统数据源-merged-MID')

# %%
# | hide
import nbdev

nbdev.nbdev_export()

# %% [markdown]
# <div>
# <link rel="stylesheet" href="https://gradio.s3-us-west-2.amazonaws.com/2.6.5/static/bundle.css">
# <div id="target"></div>
# <script src="https://gradio.s3-us-west-2.amazonaws.com/2.6.5/static/bundle.js"></script>
# <script>
# launchGradioFromSpaces("abidlabs/question-answering", "#target")
# </script>
# </div>
